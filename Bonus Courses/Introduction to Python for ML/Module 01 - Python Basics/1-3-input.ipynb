# %%
name = input("What is your name? ")

print(name)

# %%
age = input("What is your age? ")

print(age, type(age))

# %%
age = input("What is your age? ") # String

age = int(age) # String is converted to integer

print(age, type(age))

# %%
height = float(input("Height? "))

height = height + 0.2

print(height, type(height))

# %%
area = input("Area: ")

print(area)
