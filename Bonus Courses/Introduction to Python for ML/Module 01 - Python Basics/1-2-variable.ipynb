# %%
phone_number = 456249

print(phone_number)
# Out:
# 456249

# %%
name = "Phitron"

print(name)
# Out:
# Phitron

# %%
age = 20
height = 5.6
name = "Mahfuz Zayn"
is_passed = True

print(type(age), type(height), type(name), type(is_passed))

print(age, height, name, is_passed)

age = 20.5

print(type(age))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>
# 20 5.6 Mahfuz Zayn True
# <class 'float'>
