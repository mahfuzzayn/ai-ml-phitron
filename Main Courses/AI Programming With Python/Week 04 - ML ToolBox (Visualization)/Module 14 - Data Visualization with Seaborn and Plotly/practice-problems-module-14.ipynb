# %% [markdown]
# ### Problem 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("./sales.csv")

data
# Out:
#            date  sales
# 0    2025-01-01  12500
# 1    2025-01-02  13800
# 2    2025-01-03  14200
# 3    2025-01-04  15100
# 4    2025-01-05  14900
# ..          ...    ...
# 115  2025-04-26  36500
# 116  2025-04-27  38200
# 117  2025-04-28  39900
# 118  2025-04-29  41500
# 119  2025-04-30  40100
#
# [120 rows x 2 columns]

# %%
plt.xlabel("Sales")
plt.ylabel("Date")
plt.title("Dataset Sales vs Date")

plt.plot(data['sales'], data['date'])
plt.show()

# %% [markdown]
# ### Problem 2

# %%
students = pd.read_csv("./student_dataset_complete.csv")

students
# Out:
#     number_courses  time_study   Marks  student_id  class_level  subject  \
# 0                3       4.508  19.202           1           10  Science
# 1                4       0.096   7.734           2           12     Math
# 2                4       3.133  13.811           3           11  Science
# 3                6       7.909  53.018           4           10  Science
# 4                8       7.811  55.299           5           11  English
# ..             ...         ...     ...         ...          ...      ...
# 95               6       3.561  19.128          96           11  English
# 96               3       0.301   5.609          97           10  Science
# 97               4       7.163  41.444          98           11     Math
# 98               7       0.309  12.027          99           12     Math
# 99               3       6.335  32.357         100           12  Science
#
#     study_hours  test_score  week  attendance_rate gender  hostel  \
# ...

# %%
sns.lineplot(data=students, x='study_hours', y='Marks', hue='gender')
# Out:
# <Axes: xlabel='study_hours', ylabel='Marks'>

# %% [markdown]
# ### Problem 3

# %%
sns.relplot(data=students, x='study_hours', y='Marks', col='subject')

# %% [markdown]
# ### Problem 4

# %%
sns.jointplot(data=students, x='Marks', kind='kde')

# %% [markdown]
# ### Problem 5

# %%
sns.kdeplot(data=students,x='study_hours')
# Out:
# <Axes: xlabel='study_hours', ylabel='Density'>

# %% [markdown]
# ### Problem 6

# %%
# Using Count plot

sns.countplot(data=students, x='subject')
# Out:
# <Axes: xlabel='subject', ylabel='count'>

# %% [markdown]
# ### Problem 7

# %%
sns.lmplot(data=students, x='study_hours', y='Marks', hue='gender')

# %% [markdown]
# ### Problem 8

# %%
students_pp = students[['Marks', 'test_score', 'attendance_rate', 'Tshirt_size']]

students_pp
# Out:
#      Marks  test_score  attendance_rate  Tshirt_size
# 0   19.202      19.202             0.89            2
# 1    7.734       7.734             0.98            3
# 2   13.811      13.811             0.83            3
# 3   53.018      53.018             0.92            4
# 4   55.299      55.299             0.80            4
# ..     ...         ...              ...          ...
# 95  19.128      19.128             0.94            3
# 96   5.609       5.609             0.83            3
# 97  41.444      41.444             0.97            1
# 98  12.027      12.027             0.98            1
# 99  32.357      32.357             0.95            2
#
# [100 rows x 4 columns]

# %%
sns.pairplot(data=students_pp)
