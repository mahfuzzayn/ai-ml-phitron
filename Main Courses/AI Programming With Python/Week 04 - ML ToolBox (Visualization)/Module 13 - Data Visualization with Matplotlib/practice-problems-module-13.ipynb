# %% [markdown]
# ### Problem 1
# 1. Add New Column and Save File
# You have a DataFrame with column Price.
#  Create a new column Discounted_Price with (10% discounted price).
#  Save the modified DataFrame as discounted_products.csv.

# %%
import pandas as pd

df = pd.read_csv("./Practice.csv")

df['Discounted_Price'] = df['Price'] * 0.9

df.to_csv('discounted_products.csv')

# %% [markdown]
# ### Problem 2
#
# 2. Check Duplicates and Remove Them
# Column: EmployeeID
#  Tasks:
# Count duplicate entries
#
#
# Remove duplicates
#
#
# Display cleaned DataFrame

# %%
df
# Out:
#    EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0        E101        Alice  25.0  50000.0   1200      85      90      88
# 1        E102          Bob  30.0  60000.0   1500      78      82      80
# 2        E103      Charlie  22.0  52000.0   1100      92      95      90
# 3        E101        Alice  25.0  50000.0   1200      85      90      88
# 4        E104        David  45.0  80000.0   2500      88      85      89
# 5        E105          Eve  29.0  58000.0   1300      76      79      81
# 6        E106        Frank   NaN  75000.0   2200      90      91      92
# 7        E107        Grace  34.0      NaN   1900      81      83      80
# 8        E108        Heidi  38.0      NaN   1800      84      86      88
# 9        E109         Ivan  26.0  53000.0   1400      95      92      94
# 10       E102          Bob  30.0  60000.0   1500      78      82      80
#
#     Discounted_Price
# 0             1080.0
# 1             1350.0
# 2              990.0
# ...

# %%
df['EmployeeID'].duplicated().count()
df.drop_duplicates(subset=['EmployeeID'], inplace=True)

df
# Out:
#   EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0       E101        Alice  25.0  50000.0   1200      85      90      88
# 1       E102          Bob  30.0  60000.0   1500      78      82      80
# 2       E103      Charlie  22.0  52000.0   1100      92      95      90
# 4       E104        David  45.0  80000.0   2500      88      85      89
# 5       E105          Eve  29.0  58000.0   1300      76      79      81
# 6       E106        Frank   NaN  75000.0   2200      90      91      92
# 7       E107        Grace  34.0      NaN   1900      81      83      80
# 8       E108        Heidi  38.0      NaN   1800      84      86      88
# 9       E109         Ivan  26.0  53000.0   1400      95      92      94
#
#    Discounted_Price
# 0            1080.0
# 1            1350.0
# 2             990.0
# 4            2250.0
# 5            1170.0
# 6            1980.0
# 7            1710.0
# 8            1620.0
# 9            1260.0

# %% [markdown]
# ### Problem 3
# 3. Handle Missing Values
# Columns: Age, Salary
#  Tasks:
# Count missing values
#
#
# Fill missing Age with mean age
#
#
# Drop rows where Salary is missing

# %%
df = pd.read_csv("./Practice.csv")

df['Age'].isnull().sum()

df['Age'] = df['Age'].fillna(df['Age'].mean())
display(df)

df.dropna(subset=['Salary'], how='any')
display(df)
# Out:
#    EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3
# 0        E101        Alice  25.0  50000.0   1200      85      90      88
# 1        E102          Bob  30.0  60000.0   1500      78      82      80
# 2        E103      Charlie  22.0  52000.0   1100      92      95      90
# 3        E101        Alice  25.0  50000.0   1200      85      90      88
# 4        E104        David  45.0  80000.0   2500      88      85      89
# 5        E105          Eve  29.0  58000.0   1300      76      79      81
# 6        E106        Frank  30.4  75000.0   2200      90      91      92
# 7        E107        Grace  34.0      NaN   1900      81      83      80
# 8        E108        Heidi  38.0      NaN   1800      84      86      88
# 9        E109         Ivan  26.0  53000.0   1400      95      92      94
# 10       E102          Bob  30.0  60000.0   1500      78      82      80
#    EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3
# ...

# %% [markdown]
# ### Problem 4
# 4. Apply Statistical Functions
# Columns: Marks1, Marks2, Marks3
#  Tasks:
# Calculate mean, max for each subject
#
#
# Compute total marks per student
#
#
# Find standard deviation of total marks

# %%
df = pd.read_csv("./Practice.csv")

# 1
marks1_mean = df['Marks1'].mean()
marks1_max = df['Marks1'].max()
marks2_mean = df['Marks2'].mean()
marks2_max = df['Marks2'].max()
marks3_mean = df['Marks3'].mean()
marks3_max = df['Marks3'].max()

display(marks1_mean)
display(marks1_max)
display(marks2_mean)
display(marks2_max)
display(marks3_mean)
display(marks3_max)

# 2
df['Total Marks'] = df['Marks1'] + df['Marks2'] + df['Marks3']
display(df['Total Marks'])

# 3
print("Standard Deviation of Total Marks: " + str(df['Total Marks'].std()))
# Out:
# np.float64(84.72727272727273)
# np.int64(95)
# np.float64(86.81818181818181)
# np.int64(95)
# np.float64(86.36363636363636)
# np.int64(94)
# 0     263
# 1     240
# 2     277
# 3     263
# 4     262
# 5     236
# 6     273
# 7     244
# 8     258
# 9     281
# 10    240
# Name: Total Marks, dtype: int64
# Standard Deviation of Total Marks: 15.839536265020799

# %% [markdown]
# ### Problem 5
# 5. Histogram, Bar, Scatter, Pie
# Create:
# Histogram of Age
# Scatter plot (Age vs Salary)
# Scatter plot ( Price vs Discounted Price)

# %%
import matplotlib.pyplot as plt

# Histogram of Age

age = [10, 23, 13, 14, 16, 19, 22, 40, 45, 55, 42, 44, 59, 23, 32, 50, 55, 52, 64, 65, 80, 85, 77, 90, 100]

plt.xlabel("Age")
plt.ylabel("Number of Frequency (Age)")
plt.title("Histogram of Age")

plt.hist(age, color='#3498db', edgecolor='black', label='Age', bins=15)
plt.legend()
plt.show()

# %%
# Scatter plot (Age vs Salary)

age = [10, 23, 13, 14, 16, 19, 22, 40, 45, 55, 42, 44, 59, 23, 32, 50, 55, 52, 64, 65, 80, 85, 77, 90, 100]
salary = [
    0, 37483, 0, 0, 0, 34308, 38238, 117845, 91487, 91487, 
    118688, 106511, 87957, 37712, 60365, 88014, 98629, 66300, 
    27750, 39377, 34871, 48142, 35919, 30876, 59656
]

plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Scatter plot (Age vs Salary)")

plt.scatter(age, salary, color='violet', edgecolor='black')
plt.show()

# %%
# Scatter plot ( Price vs Discounted Price) 

price = [
    107.84, 261.97, 300.28, 32.76, 307.70, 93.56, 41.88, 474.95, 483.16, 406.11, 
    159.26, 57.86, 345.27, 225.67, 69.80, 252.64, 26.85, 455.57, 136.80, 334.64
]
discounted_price = [
    83.61, 181.28, 204.59, 27.06, 157.59, 55.20, 21.95, 257.46, 319.29, 215.75, 
    137.70, 47.54, 304.50, 173.74, 51.97, 199.95, 15.26, 345.00, 107.75, 228.53
]

plt.xlabel("Price")
plt.ylabel("Discounted Price")
plt.title("Scatter plot (Price vs Discounted Price)")

plt.scatter(price, discounted_price, color='blue', edgecolor='black')
plt.show()

# %% [markdown]
# ### Problem 6
# 6.
# Dataset :https://drive.google.com/file/d/1Sy7rA0G9gTmeItVZ-XlugkKF4CPPqvxU/view?usp=sharing
#
# Load the dataset from the URL into a pandas DataFrame.
# Create a scatter plot with Study_Hours on the X-axis and IQ on the Y-axis.
# Create a scatter plot with Shoe_Size on the X-Axis and Study_Hours on the Y-axis.
# Create a histogram of Shoe_Size
# Add a title and axis labels to make the plot clear.
# After you plot it, answer the question: Does there appear to be a correlation?

# %%
df = pd.read_csv("./student-IQdata.csv")

plt.xlabel("Study Hour")
plt.ylabel("IQ Score")
plt.title("Scatter plot (Study Hours vs IQ Score)")

plt.scatter(df['Study_Hour'], df['IQ_Score'])
plt.show();

# %%
plt.xlabel("Shoe Size")
plt.ylabel("Study Hours")
plt.title("Scatter plot (Shoe Size vs Study Hours)")

plt.scatter(df['Shoe_Size'], df['Study_Hour'])
plt.show();

# %% [markdown]
# Answer: There is no correlation between Shoe Sizes and Study Hours as they are not a connected topic.

# %%
plt.xlabel("Shoe Size")
plt.ylabel("Number of Frequency (Shoe Size)")
plt.title("Histogram (Shoe Size)")

plt.hist(df['Shoe_Size'], color='#3498db', edgecolor='black')
plt.show();
