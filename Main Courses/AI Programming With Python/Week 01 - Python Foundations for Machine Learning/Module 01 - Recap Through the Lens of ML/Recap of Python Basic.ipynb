# %%
a = int("10")
# Out:
# <class 'int'>

# %%
b = 10.5

print(type(b))
# Out:
# <class 'float'>

# %%
data = input()

print(data)
print(type(data))
# Out:
#  Name
# Name
# <class 'str'>

# %%
a = input()
a = int(a)

print(a)
print(type(a))
# Out:
#  10
# 10
# <class 'int'>

# %%
row_number = input()

numbers = row_number.split()

a = int(numbers[0])

print(a)
print(type(a))

print(numbers)
# Out:
#  10 20 30
# 10
# <class 'int'>
# ['10', '20', '30']

# %%
# 1-3: Conditional Statement
# Image to Model Training Prediction based Conditional Checking
