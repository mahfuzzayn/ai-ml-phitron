# %% [markdown]
# ### 1-2 Analytical View of a Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("titanic_data_updated.csv")

# Our data has 891 data row, and 12 columns means feature
df.shape

print(f"Total potential feature:{df.shape[1]}")
print(f"Total sample data: {df.shape[0]}")
# Out:
# Total potential feature:12
# Total sample data: 891

# %%
# First 10 row
# df.head(10)

# Random 10
df.sample(10)
# Out:
#      PassengerId Survived  Pclass                              Name     Sex  \
# 889          890      yes   first             Behr, Mr. Karl Howell    male
# 237          238      yes  second  Collyer, Miss. Marjorie "Lottie"  female
# 484          485      yes   first           Bishop, Mr. Dickinson H    male
# 322          323      yes  second         Slayter, Miss. Hilda Mary  female
# 288          289      yes  second              Hosono, Mr. Masabumi    male
# 786          787      yes   third         Sjoblom, Miss. Anna Sofia  female
# 804          805      yes   third           Hedman, Mr. Oskar Arvid    male
# 674          675       no  second        Watson, Mr. Ennis Hastings    male
# 80            81       no   third              Waelens, Mr. Achille    male
# 372          373       no   third        Beavan, Mr. William Thomas    male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 889  26.0      0      0      111369  30.0000  C148        C
# 237   8.0      0      2  C.A. 31921  26.2500   NaN        S
# 484  25.0      1      0       11967  91.0792   B49        C
# 322  30.0      0      0      234818  12.3500   NaN        Q
# 288  42.0      0      0      237798  13.0000   NaN        S
# 786  18.0      0      0     3101265   7.4958   NaN        S
# 804  27.0      0      0      347089   6.9750   NaN        S
# 674   NaN      0      0      239856   0.0000   NaN        S
# 80   22.0      0      0      345767   9.0000   NaN        S
# 372  19.0      0      0      323951   8.0500   NaN        S
